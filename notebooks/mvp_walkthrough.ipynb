# %% [markdown]
# # MVP Walkthrough — Churn & Expansion Copilot
#
# Ejecutar desde la raíz del proyecto:
#
# ```bash
# python src/generate_data.py
# python src/train.py
# python src/predict_and_plan.py
# ```
